# %% [markdown]
# # Tutorial
# This tutorial shows how to use the mllp package.

# %%
import torch
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

from mllp.models import MLLP
from mllp.utils import DBEncoder

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# /var/folders/x3/cd482yl51lg4jcy2wdj4q9sc0000gn/T/ipykernel_2671/2218189224.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Prepare data
# We use the [breast cancer wisconsin dataset](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)) for example.
# X_df stores the feature values of all the instances.
# y_df stores the class labels of all the instances.
# f_df stores the feature names and feature types (continuous or discrete).

# %%
data = load_breast_cancer()

X_df = pd.DataFrame(data['data'], columns=data['feature_names'])
y_df = pd.DataFrame(data['target'], columns=['class'])
f_df = pd.DataFrame(zip(data['feature_names'], ['continuous'] * len(data.feature_names)))
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, train_size=0.8)

# %% [markdown]
# ## Discrete and binarize data

# %% [markdown]
# For features in the data set are continuous (real numbers), we need to discrete them first.
# After data discretization, we use the one-hot encoding to encode all the features and the class.
# `DBEncoder` does all of this for us.

# %%
db_enc = DBEncoder(f_df, discrete=True)
db_enc.fit(X_train, y_train)
X_train, y_train = db_enc.transform(X_train, y_train)
X_test, y_test = db_enc.transform(X_test, y_test)
# Out:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c_cnt1[row[1]] += 1
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if i + 1 < r and row[0] == df.iloc[i + 1][0]:
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/mllp/discretizer.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   boundaries.append(df.iloc[max_pos][0])
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/venv/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# /Users/gonzalojaimovitch/Documents/projects/tfm/git/mllp/venv/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %% [markdown]
# `DBEncoder` uses the recursive minimal entropy partitioning algorithm for data discretization.
# The class member `me_discretizer` is the discretizer and we can get the partition boundaries by:

# %%
db_enc.me_discretizer.boundaries
# Out:
# defaultdict(list,
#             {'mean radius': [13.16, 15.04, 17.85],
#              'mean texture': [18.42],
#              'mean perimeter': [85.24, 96.39, 114.6],
#              'mean area': [530.6, 690.2, 992.1],
#              'mean smoothness': [0.08853],
#              'mean compactness': [0.1021, 0.1483],
#              'mean concavity': [0.05192, 0.0905, 0.1374],
#              'mean concave points': [0.02738, 0.05102, 0.07857],
#              'mean symmetry': [0.1718, 0.2057],
#              'mean fractal dimension': [],
#              'radius error': [0.1935, 0.4202, 0.5619],
#              'texture error': [],
#              'perimeter error': [1.529, 2.759, 4.36],
#              'area error': [18.51, 31.24, 53.65],
#              'smoothness error': [],
#              'compactness error': [0.0182],
#              'concavity error': [0.01099, 0.02095],
#              'concave points error': [0.009064, 0.01167],
#              'symmetry error': [0.04197],
#              'fractal dimension error': [0.002671],
#              'worst radius': [14.85, 16.77, 19.82],
#              'worst texture': [23.31, 29.26],
#              'worst perimeter': [101.6, 105.9, 120.3],
#              'worst area': [694.4, 880.8],
#              'worst smoothness': [0.1388],
#              'worst compactness': [0.1792, 0.2809, 0.3454],
#              'worst concavity': [0.2079, 0.2604, 0.3755],
#              'worst concave points': [0.1095, 0.1453],
#              'worst symmetry': [0.2806, 0.3604],
#              'worst fractal dimension': [0.09702]})

# %% [markdown]
# ## Set the MLLP
# Set the network structure, device, rate of random binarization and whether use the NOT (~) operator.
# Run `MLLP?` for more information.

# %%
net_structure = [X_train.shape[-1], 32, y_train.shape[-1]]
# below is a more complex MLLP structure that can be used for a complex data set
# net_structure = [X_train.shape[-1], 128, 128, 64, y_train.shape[-1]]
net = MLLP(net_structure,
           device=device,
           random_binarization_rate=0.0,
           use_not=False)
net.to(device)
# Out:
# MLLP(
#   (conj0): ConjunctionLayer(
#     (randomly_binarize_layer): RandomBinarizationLayer()
#   )
#   (disj0): DisjunctionLayer(
#     (randomly_binarize_layer): RandomBinarizationLayer()
#   )
# )

# %% [markdown]
# ## Train the MLLP
# Set the parameters for training and train the MLLP. The log is displayed during the training.
# Run `MLLP.train?` for more information.

# %%
training_log = net.train(
    X_train,
    y_train,
    lr=0.005,
    batch_size=16,
    epoch=100,
    lr_decay_rate=0.75,
    lr_decay_epoch=100,
    weight_decay=1e-7)
# Out:
# [INFO] - LR is set to 0.005
# [INFO] - epoch: 0, loss: 7.055806383490562
# [INFO] - ------------------------------------------------------------
# [INFO] - On Training Set:
# 	Accuracy of MLLP Model: 0.5714285714285714
# 	Accuracy of CRS  Model: 0.42857142857142855
# [INFO] - On Training Set:
# 	F1 Score of MLLP Model: 0.36363636363636365
# 	F1 Score of CRS  Model: 0.3
# [INFO] - ------------------------------------------------------------
# [INFO] - epoch: 1, loss: 3.5095775574445724
# [INFO] - epoch: 2, loss: 2.16383795812726
# [INFO] - epoch: 3, loss: 1.8785468265414238
# [INFO] - epoch: 4, loss: 1.7090795412659645
# [INFO] - epoch: 5, loss: 1.5704785380512476
# [INFO] - ------------------------------------------------------------
# [INFO] - On Training Set:
# 	Accuracy of MLLP Model: 1.0
# 	Accuracy of CRS  Model: 0.2857142857142857
# [INFO] - On Training Set:
# 	F1 Score of MLLP Model: 1.0
# 	F1 Score of CRS  Model: 0.2222222222222222
# [INFO] - ------------------------------------------------------------
# [INFO] - epoch: 6, loss: 1.4546841094270349
# [INFO] - epoch: 7, loss: 1.3756329277530313
# [INFO] - epoch: 8, loss: 1.2601300068199635
# [INFO] - epoch: 9, loss: 1.1172014772891998
# [INFO] - epoch: 10, loss: 1.0696923295035958
# [INFO] - ------------------------------------------------------------
# [INFO] - On Training Set:
# 	Accuracy of MLLP Model: 1.0
# 	Accuracy of CRS  Model: 0.7142857142857143
# [INFO] - On Training Set:
# 	F1 Score of MLLP Model: 1.0
# 	F1 Score of CRS  Model: 0.7083333333333333
# [INFO] - ------------------------------------------------------------
# [INFO] - epoch: 11, loss: 0.977364556863904
# [INFO] - epoch: 12, loss: 0.8610349344089627
# [INFO] - epoch: 13, loss: 0.7962807612493634
# [INFO] - epoch: 14, loss: 0.7639670232310891
# [INFO] - epoch: 15, loss: 0.6971487384289503
# [INFO] - ------------------------------------------------------------
# [INFO] - On Training Set:
# 	Accuracy of MLLP Model: 1.0
# 	Accuracy of CRS  Model: 1.0
# [INFO] - On Training Set:
# 	F1 Score of MLLP Model: 1.0
# 	F1 Score of CRS  Model: 1.0
# [INFO] - ------------------------------------------------------------
# [INFO] - epoch: 16, loss: 0.6898286377545446
# [INFO] - epoch: 17, loss: 0.6253812696086243
# [INFO] - epoch: 18, loss: 0.599695363547653
# [INFO] - epoch: 19, loss: 0.6369251814903691
# [INFO] - epoch: 20, loss: 0.5686192677821964
# [INFO] - ------------------------------------------------------------
# [INFO] - On Training Set:
# 	Accuracy of MLLP Model: 1.0
# 	Accuracy of CRS  Model: 1.0
# [INFO] - On Training Set:
# 	F1 Score of MLLP Model: 1.0
# 	F1 Score of CRS  Model: 1.0
# [INFO] - ------------------------------------------------------------
# [INFO] - epoch: 21, loss: 0.5205424625892192
# [INFO] - epoch: 22, loss: 0.518741293810308
# [INFO] - epoch: 23, loss: 0.48425920034060255
# [INFO] - epoch: 24, loss: 0.47374021727591753
# [INFO] - epoch: 25, loss: 0.46240832965122536
# [INFO] - ------------------------------------------------------------
# [INFO] - On Training Set:
# 	Accuracy of MLLP Model: 1.0
# 	Accuracy of CRS  Model: 1.0
# [INFO] - On Training Set:
# 	F1 Score of MLLP Model: 1.0
# 	F1 Score of CRS  Model: 1.0
# [INFO] - ------------------------------------------------------------
# [INFO] - epoch: 26, loss: 0.450099011301063
# [INFO] - epoch: 27, loss: 0.44854478200431913
# [INFO] - epoch: 28, loss: 0.42652130452916026
# [INFO] - epoch: 29, loss: 0.416051944863284
# [INFO] - epoch: 30, loss: 0.4182050464733038
# [INFO] - ------------------------------------------------------------
# [INFO] - On Training Set:
# 	Accuracy of MLLP Model: 1.0
# 	Accuracy of CRS  Model: 1.0
# [INFO] - On Training Set:
# 	F1 Score of MLLP Model: 1.0
# 	F1 Score of CRS  Model: 1.0
# [INFO] - ------------------------------------------------------------
# [INFO] - epoch:
# [INFO] - ------------------------------------------------------------
# [INFO] - On Training Set:
# 	Accuracy of MLLP Model: 1.0
# 	Accuracy of CRS  Model: 1.0
# [INFO] - On Training Set:
# 	F1 Score of MLLP Model: 1.0
# 	F1 Score of CRS  Model: 1.0
# [INFO] - ------------------------------------------------------------
# [INFO] - epoch: 86, loss: 0.10312542859492169
# [INFO] - epoch: 87, loss: 0.09807016857394046
# [INFO] - epoch: 88, loss: 0.09621636506989262
# [INFO] - epoch: 89, loss: 0.08979482671833239
# [INFO] - epoch: 90, loss: 0.13316618881071918
# [INFO] - ------------------------------------------------------------
# [INFO] - On Training Set:
# 	Accuracy of MLLP Model: 0.8571428571428571
# 	Accuracy of CRS  Model: 1.0
# [INFO] - On Training Set:
# 	F1 Score of MLLP Model: 0.7878787878787878
# 	F1 Score of CRS  Model: 1.0
# [INFO] - ------------------------------------------------------------
# [INFO] - epoch: 91, loss: 0.09477154429805523
# [INFO] - epoch: 92, loss: 0.09080260460291356
# [INFO] - epoch: 93, loss: 0.08711835911705634
# [INFO] - epoch: 94, loss: 0.08183490720706743
# [INFO] - epoch: 95, loss: 0.08700914598978216
# [INFO] - ------------------------------------------------------------
# [INFO] - On Training Set:
# 	Accuracy of MLLP Model: 1.0
# 	Accuracy of CRS  Model: 1.0
# [INFO] - On Training Set:
# 	F1 Score of MLLP Model: 1.0
# 	F1 Score of CRS  Model: 1.0
# [INFO] - ------------------------------------------------------------
# [INFO] - epoch: 96, loss: 0.08271234934136373
# [INFO] - epoch: 97, loss: 0.07991321962254005
# [INFO] - epoch: 98, loss: 0.08134469724420512
# [INFO] - epoch: 99, loss: 0.07339840237736439

# %% [markdown]
# ## Test the trained MLLP and extracted CRS

# %%
acc, acc_b, f1, f1_b = net.test(X_test, y_test, need_transform=True)

print('Accuracy of MLLP Model: {}'
      '\nAccuracy of CRS  Model: {}'
      '\nF1 Score of MLLP Model: {}'
      '\nF1 Score of CRS  Model: {}'.format(acc, acc_b, f1, f1_b))
# Out:
# Accuracy of MLLP Model: 0.9385964912280702
# Accuracy of CRS  Model: 0.9122807017543859
# F1 Score of MLLP Model: 0.9383640997914575
# F1 Score of CRS  Model: 0.9122536945812808

# %% [markdown]
# ## Display the extracted CRS

# %%
net.concept_rule_set_print(X_fname=db_enc.X_fname, y_fname=db_enc.y_fname, eliminate_redundancy=True)
# Out:
# ------------------------------------------------------------------------------------------
#  class_0:
# 	       r1,0:	 [' mean radius_(12.32, 15.0]', ' mean perimeter_(81.09, 98.22]', ' mean smoothness_>0.08992', ' worst area_(694.4, 862.0]', ' worst smoothness_>0.136', ' worst compactness_>0.2809']
# 	       r1,4:	 [' mean radius_(12.32, 15.0]', ' mean texture_>19.6', ' mean perimeter_(81.09, 98.22]', ' mean smoothness_>0.08992', ' worst texture_>24.85', ' worst smoothness_>0.136']
# 	       r1,9:	 [' worst radius_(16.76, 18.22]', ' worst texture_>24.85', ' worst perimeter_(107.1, 120.3]', ' worst area_(862.0, 1032.0]', ' worst concavity_(0.2151, 0.3662]']
# 	      r1,11:	 [' worst perimeter_>120.3']
# 	      r1,13:	 [' mean symmetry_<=0.1714', ' worst radius_(16.76, 18.22]', ' worst perimeter_(107.1, 120.3]', ' worst area_(862.0, 1032.0]', ' worst concavity_(0.2151, 0.3662]']
# 	      r1,15:	 [' mean texture_>19.6', ' mean compactness_(0.05113, 0.1021]', ' worst radius_(14.98, 16.76]', ' worst texture_>24.85', ' worst area_(694.4, 862.0]', ' worst concave points_(0.1095, 0.1423]']
# 	      r1,18:	 [' mean smoothness_>0.08992', ' mean compactness_>0.1552', ' radius error_(0.1935, 0.4101]', ' worst texture_>24.85', ' worst concavity_>0.3662']
# 	      r1,24:	 [' mean texture_>19.6', ' mean concave points_(0.04908, 0.07857]', ' worst texture_>24.85', ' worst concave points_(0.1423, 0.175]']
# 	      r1,25:	 [' mean smoothness_>0.08992', ' mean concavity_>0.1115', ' concave points error_>0.01164', ' worst texture_>24.85']
# 	      r1,27:	 [' worst perimeter_(107.1, 120.3]', ' worst area_(862.0, 1032.0]', ' worst smoothness_>0.136', ' worst fractal dimension_>0.0927']
# 	      r1,28:	 [' mean smoothness_>0.08992', ' mean compactness_>0.1552', ' mean concavity_>0.1115', ' worst concavity_>0.3662', ' worst concave points_>0.175']
#  class_1:
# 	       r1,3:	 [' mean texture_<=19.6', ' worst concavity_<=0.2151', ' worst symmetry_<=0.3557']
# 	       r1,5:	 [' mean texture_<=19.6', ' mean fractal dimension_>0.05534', ' worst texture_<=24.85', ' worst perimeter_<=101.6', ' worst concavity_<=0.2151']
# 	       r1,6:	 [' mean concave points_<=0.04908', ' mean fractal dimension_>0.05534', ' worst perimeter_<=101.6', ' worst concavity_<=0.2151', ' worst concave points_<=0.1095']
# 	      r1,12:	 [' concave points error_<=0.008849', ' worst perimeter_<=101.6', ' worst smoothness_<=0.136']
# 	      r1,16:	 [' compactness error_>0.01834', ' worst perimeter_<=101.6', ' worst symmetry_<=0.3557']
# 	      r1,17:	 [' mean radius_(12.32, 15.0]', ' mean perimeter_(81.09, 98.22]', ' mean area_(471.3, 689.5]', ' radius error_(0.1935, 0.4101]', ' worst smoothness_<=0.136']
# 	      r1,22:	 [' mean texture_<=19.6', ' mean fractal dimension_>0.05534', ' area error_<=18.49', ' compactness error_<=0.01834', ' worst texture_<=24.85', ' worst symmetry_<=0.3557']
# 	      r1,23:	 [' mean radius_(12.32, 15.0]', ' mean texture_<=19.6', ' mean perimeter_(81.09, 98.22]', ' mean area_(471.3, 689.5]', ' worst smoothness_<=0.136']
# 	      r1,26:	 [' mean texture_<=19.6', ' mean fractal dimension_>0.05534', ' perimeter error_<=1.75', ' compactness error_<=0.01834', ' worst texture_<=24.85', ' worst perimeter_(107.1, 120.3]', ' worst symmetry_<=0.3557', ' worst fractal dimension_<=0.0927']
# 	      r1,29:	 [' worst perimeter_<=101.6', ' worst area_<=694.4']
# 	      r1,30:	 [' mean radius_<=12.32', ' mean perimeter_<=81.09', ' mean area_<=471.3', ' mean concave points_<=0.04908', ' worst perimeter_<=101.6']
